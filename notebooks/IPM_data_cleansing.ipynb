# %%
import pandas as pd
import numpy as np
import missingno as msno

data_fpath = "../data/multidimensional.csv"
pd.set_option('display.max_columns', 100)
pd.set_option("display.max_colwidth", 500)

# %%
df = pd.read_csv(data_fpath)
numeric_features = df.select_dtypes(include=[np.number])
categorical_features = df.select_dtypes(exclude=[np.number])
print(df.shape, numeric_features.shape, categorical_features.shape)
# Out:
# (2200, 93) (2200, 57) (2200, 36)

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
numeric_features.columns
# Out:
# Index(['tries_amount', 'questionnaire_amount', 'dimensions_amount',
#        'document_amount', 'current_try', 'q_0_age_value', 'q_0_school_value',
#        'q_0_taxes_value', 'q_0_political_views_value',
#        'q_0_consideration_value', 'q_0_southern_border_value',
#        'q_0_environment_value', 'q_0_time_elapsed', 'q_0_accesses',
#        'q_1_farmers_answer', 'q_1_farmers_value', 'q_1_time_elapsed',
#        'q_1_accesses', 'q_2_marks_answer', 'q_2_marks_value',
#        'q_2_time_elapsed', 'q_2_accesses', 'q_3_athletics_answer',
#        'q_3_athletics_value', 'q_3_time_elapsed', 'q_3_accesses', 'doc_index',
#        'doc_date', 'doc_ground_truth_value', 'doc_overall-truthfulness_value',
#        'doc_overall-truthfulness_justification', 'doc_confidence_value',
#        'doc_confidence_justification', 'doc_confidence_url',
#        'doc_correctness_value', 'doc_correctness_justification',
#        'doc_correctness_url', 'doc_neutrality_value',
#        'doc_neutrality_justification', 'doc_neutrality_url',
#        'doc_comprehensibility_value', 'doc_comprehensibility_justification',
#        'doc_comprehensibility_url', 'doc_precision_value',
#        'doc_precision_justification', 'doc_precision_url',
#        'doc_completeness_value', 'doc_completeness_justification',
#        'doc_completeness_url', 'doc_speaker's-trustworthiness_value',
#        'doc_speaker's-trustworthiness_justification',
#        'doc_speaker's-trustworthiness_url', 'doc_informativeness_value',
#        'doc_informativeness_justification', 'doc_informativeness_url',
#        'doc_accesses', 'doc_time_elapsed'],
#       dtype='object')

# %%
categorical_features.columns
# Out:
# Index(['unit_id', 'q_0_age_question', 'q_0_age_answer', 'q_0_school_question',
#        'q_0_school_answer', 'q_0_taxes_question', 'q_0_taxes_answer',
#        'q_0_political_views_question', 'q_0_political_views_answer',
#        'q_0_consideration_question', 'q_0_consideration_answer',
#        'q_0_southern_border_question', 'q_0_southern_border_answer',
#        'q_0_environment_question', 'q_0_environment_answer',
#        'q_1_farmers_question', 'q_2_marks_question', 'q_3_athletics_question',
#        'doc_name', 'doc_statement', 'doc_claimant', 'doc_originatedFrom',
#        'doc_ground_truth_abc_label', 'doc_ground_truth_abc_verdict',
#        'doc_ground_truth_politifact_label', 'doc_source',
#        'doc_overall-truthfulness_label', 'doc_overall-truthfulness_url',
#        'doc_confidence_label', 'doc_correctness_label', 'doc_neutrality_label',
#        'doc_comprehensibility_label', 'doc_precision_label',
#        'doc_completeness_label', 'doc_speaker's-trustworthiness_label',
#        'doc_informativeness_label'],
#       dtype='object')

# %%
numeric_features.describe()
# Out:
#        tries_amount  questionnaire_amount  dimensions_amount  document_amount  \
# count        2200.0                2200.0             2200.0           2200.0
# mean           10.0                   4.0                9.0             11.0
# std             0.0                   0.0                0.0              0.0
# min            10.0                   4.0                9.0             11.0
# 25%            10.0                   4.0                9.0             11.0
# 50%            10.0                   4.0                9.0             11.0
# 75%            10.0                   4.0                9.0             11.0
# max            10.0                   4.0                9.0             11.0
#
#        current_try  q_0_age_value  q_0_school_value  q_0_taxes_value  \
# count  2200.000000    2200.000000       2200.000000      2200.000000
# mean      1.015000       2.175000          3.085000         4.295000
# std       0.157437       0.839461          1.099238         1.974778
# min       1.000000       1.000000          1.000000         0.000000
# 25%       1.000000       2.000000          2.750000         3.000000
# 50%       1.000000       2.000000          3.000000         4.000000
# 75%       1.000000       3.000000          3.000000         6.000000
# max       3.000000       4.000000          5.000000         8.000000
#
#        q_0_political_views_value  q_0_consideration_value  \
# count                 2200.00000              2200.000000
# mean                     2.24500                 0.990000
# std                      1.24727                 0.774708
# min                      0.00000                 0.000000
# 25%                      1.00000                 0.000000
# 50%                      2.00000                 1.000000
# 75%                      3.00000                 2.000000
# max                      4.00000                 3.000000
#
#        q_0_southern_border_value  q_0_environment_value  q_0_time_elapsed  \
# count                2200.000000            2200.000000       2200.000000
# mean                    0.665000               0.210000         48.200950
# std                     0.594084               0.534818         68.746757
# min                     0.000000               0.000000         10.820000
# 25%                     0.000000               0.000000         22.485000
# 50%                     1.000000               0.000000         29.970000
# 75%                     1.000000               0.000000         45.837500
# max                     2.000000               2.000000        743.820000
#
#        q_0_accesses  q_1_farmers_answer  q_1_farmers_value  q_1_time_elapsed  \
# count        2200.0                 0.0        2200.000000       2200.000000
# mean            1.0                 NaN           5.980000         46.009800
# std             0.0                 NaN           3.944195         74.876823
# min             1.0                 NaN           1.000000          3.180000
# 25%             1.0                 NaN           3.000000         15.292500
# 50%             1.0                 NaN           3.000000         25.655000
# 75%             1.0                 NaN           9.000000         46.765000
# max             1.0                 NaN          27.000000        637.380000
#
#        q_1_accesses  q_2_marks_answer  q_2_marks_value  q_2_time_elapsed  \
# count        2200.0               0.0      2200.000000       2200.000000
# mean            1.0               NaN         8.445000         32.518300
# std             0.0               NaN         3.986753         40.834394
# min             1.0               NaN         1.000000          2.940000
# 25%             1.0               NaN         5.000000         10.085000
# 50%             1.0               NaN         9.000000         18.505000
# 75%             1.0               NaN        10.000000         37.425000
# max             1.0               NaN        36.000000        301.340000
#
#        q_2_accesses  q_3_athletics_answer  q_3_athletics_value  \
# count        2200.0                   0.0          2200.000000
# mean            1.0                   NaN             7.415000
# std             0.0                   NaN            10.034867
# min             1.0                   NaN             0.000000
# 25%             1.0                   NaN             4.000000
# 50%             1.0                   NaN             5.000000
# 75%             1.0                   NaN             5.000000
# max             1.0                   NaN            80.000000
#
#        q_3_time_elapsed  q_3_accesses    doc_index     doc_date  \
# count       2200.000000        2200.0  2200.000000  2200.000000
# mean          41.252200           1.0     5.000000  2011.254545
# std           45.017395           0.0     3.162997     2.590557
# min            3.970000           1.0     0.000000  2006.000000
# 25%           16.785000           1.0     2.000000  2010.000000
# 50%           27.100000           1.0     5.000000  2012.000000
# 75%           50.965000           1.0     8.000000  2013.000000
# max          309.130000           1.0    10.000000  2015.000000
#
#        doc_ground_truth_value  doc_overall-truthfulness_value  \
# count             2200.000000                     2200.000000
# mean                 2.387273                        0.385000
# std                  1.207082                        1.302201
# min                  0.000000                       -2.000000
# 25%                  2.000000                       -1.000000
# 50%                  3.000000                        1.000000
# 75%                  3.000000                        1.000000
# max                  4.000000                        2.000000
#
#        doc_overall-truthfulness_justification  doc_confidence_value  \
# count                                     0.0           2200.000000
# mean                                      NaN              0.044091
# std                                       NaN              1.347479
# min                                       NaN             -2.000000
# 25%                                       NaN             -1.000000
# 50%                                       NaN              0.000000
# 75%                                       NaN              1.000000
# max                                       NaN              2.000000
#
#        doc_confidence_justification  doc_confidence_url  \
# count                           0.0                 0.0
# mean                            NaN                 NaN
# std                             NaN                 NaN
# min                             NaN                 NaN
# 25%                             NaN                 NaN
# 50%                             NaN                 NaN
# 75%                             NaN                 NaN
# max                             NaN                 NaN
#
#        doc_correctness_value  doc_correctness_justification  \
# count            2200.000000                            0.0
# mean                0.328182                            NaN
# std                 1.259264                            NaN
# min                -2.000000                            NaN
# 25%                -1.000000                            NaN
# 50%                 1.000000                            NaN
# 75%                 1.000000                            NaN
# max                 2.000000                            NaN
#
#        doc_correctness_url  doc_neutrality_value  \
# count                  0.0           2200.000000
# mean                   NaN              0.149091
# std                    NaN              1.276844
# min                    NaN             -2.000000
# 25%                    NaN             -1.000000
# 50%                    NaN              0.000000
# 75%                    NaN              1.000000
# max                    NaN              2.000000
#
#        doc_neutrality_justification  doc_neutrality_url  \
# count                           0.0                 0.0
# mean                            NaN                 NaN
# std                             NaN                 NaN
# min                             NaN                 NaN
# 25%                             NaN                 NaN
# 50%                             NaN                 NaN
# 75%                             NaN                 NaN
# max                             NaN                 NaN
#
#        doc_comprehensibility_value  doc_comprehensibility_justification  \
# count                  2200.000000                                  0.0
# mean                      0.811364                                  NaN
# std                       1.115991                                  NaN
# min                      -2.000000                                  NaN
# 25%                       0.000000                                  NaN
# 50%                       1.000000                                  NaN
# 75%                       2.000000                                  NaN
# max                       2.000000                                  NaN
#
#        doc_comprehensibility_url  doc_precision_value  \
# count                        0.0          2200.000000
# mean                         NaN             0.489545
# std                          NaN             1.222005
# min                          NaN            -2.000000
# 25%                          NaN             0.000000
# 50%                          NaN             1.000000
# 75%                          NaN             1.000000
# max                          NaN             2.000000
#
#        doc_precision_justification  doc_precision_url  doc_completeness_value  \
# count                          0.0                0.0             2200.000000
# mean                           NaN                NaN                0.253636
# std                            NaN                NaN                1.258797
# min                            NaN                NaN               -2.000000
# 25%                            NaN                NaN               -1.000000
# 50%                            NaN                NaN                0.000000
# 75%                            NaN                NaN                1.000000
# max                            NaN                NaN                2.000000
#
#        doc_completeness_justification  doc_completeness_url  \
# count                             0.0                   0.0
# mean                              NaN                   NaN
# std                               NaN                   NaN
# min                               NaN                   NaN
# 25%                               NaN                   NaN
# 50%                               NaN                   NaN
# 75%                               NaN                   NaN
# max                               NaN                   NaN
#
#        doc_speaker's-trustworthiness_value  \
# count                          2200.000000
# mean                              0.352273
# std                               1.194955
# min                              -2.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               2.000000
#
#        doc_speaker's-trustworthiness_justification  \
# count                                          0.0
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        doc_speaker's-trustworthiness_url  doc_informativeness_value  \
# count                                0.0                2200.000000
# mean                                 NaN                   0.387273
# std                                  NaN                   1.207082
# min                                  NaN                  -2.000000
# 25%                                  NaN                   0.000000
# 50%                                  NaN                   1.000000
# 75%                                  NaN                   1.000000
# max                                  NaN                   2.000000
#
#        doc_informativeness_justification  doc_informativeness_url  \
# count                                0.0                      0.0
# mean                                 NaN                      NaN
# std                                  NaN                      NaN
# min                                  NaN                      NaN
# 25%                                  NaN                      NaN
# 50%                                  NaN                      NaN
# 75%                                  NaN                      NaN
# max                                  NaN                      NaN
#
#        doc_accesses  doc_time_elapsed
# count   2200.000000       2198.000000
# mean       1.035455        111.261292
# std        0.226922        104.897821
# min        1.000000         17.590000
# 25%        1.000000         49.355000
# 50%        1.000000         81.835000
# 75%        1.000000        135.362500
# max        3.000000       1388.600000

# %%
numeric_features.head()
# Out:
#    tries_amount  questionnaire_amount  dimensions_amount  document_amount  \
# 0            10                     4                  9               11
# 1            10                     4                  9               11
# 2            10                     4                  9               11
# 3            10                     4                  9               11
# 4            10                     4                  9               11
#
#    current_try  q_0_age_value  q_0_school_value  q_0_taxes_value  \
# 0            1            2.0               2.0              3.0
# 1            1            2.0               2.0              3.0
# 2            1            2.0               2.0              3.0
# 3            1            2.0               2.0              3.0
# 4            1            2.0               2.0              3.0
#
#    q_0_political_views_value  q_0_consideration_value  \
# 0                        4.0                      2.0
# 1                        4.0                      2.0
# 2                        4.0                      2.0
# 3                        4.0                      2.0
# 4                        4.0                      2.0
#
#    q_0_southern_border_value  q_0_environment_value  q_0_time_elapsed  \
# 0                        1.0                    0.0              38.6
# 1                        1.0                    0.0              38.6
# 2                        1.0                    0.0              38.6
# 3                        1.0                    0.0              38.6
# 4                        1.0                    0.0              38.6
#
#    q_0_accesses  q_1_farmers_answer  q_1_farmers_value  q_1_time_elapsed  \
# 0             1                 NaN                1.0             17.98
# 1             1                 NaN                1.0             17.98
# 2             1                 NaN                1.0             17.98
# 3             1                 NaN                1.0             17.98
# 4             1                 NaN                1.0             17.98
#
#    q_1_accesses  q_2_marks_answer  q_2_marks_value  q_2_time_elapsed  \
# 0             1               NaN              9.0             23.91
# 1             1               NaN              9.0             23.91
# 2             1               NaN              9.0             23.91
# 3             1               NaN              9.0             23.91
# 4             1               NaN              9.0             23.91
#
#    q_2_accesses  q_3_athletics_answer  q_3_athletics_value  q_3_time_elapsed  \
# 0             1                   NaN                  4.0            274.19
# 1             1                   NaN                  4.0            274.19
# 2             1                   NaN                  4.0            274.19
# 3             1                   NaN                  4.0            274.19
# 4             1                   NaN                  4.0            274.19
#
#    q_3_accesses  doc_index  doc_date  doc_ground_truth_value  \
# 0             1        0.0    2013.0                     3.0
# 1             1        1.0    2013.0                     4.0
# 2             1        2.0    2013.0                     3.0
# 3             1        3.0    2008.0                     2.0
# 4             1        4.0    2010.0                     4.0
#
#    doc_overall-truthfulness_value  doc_overall-truthfulness_justification  \
# 0                             1.0                                     NaN
# 1                             2.0                                     NaN
# 2                             2.0                                     NaN
# 3                             2.0                                     NaN
# 4                             0.0                                     NaN
#
#    doc_confidence_value  doc_confidence_justification  doc_confidence_url  \
# 0                  -1.0                           NaN                 NaN
# 1                   0.0                           NaN                 NaN
# 2                   0.0                           NaN                 NaN
# 3                   2.0                           NaN                 NaN
# 4                  -1.0                           NaN                 NaN
#
#    doc_correctness_value  doc_correctness_justification  doc_correctness_url  \
# 0                    1.0                            NaN                  NaN
# 1                    2.0                            NaN                  NaN
# 2                    0.0                            NaN                  NaN
# 3                    2.0                            NaN                  NaN
# 4                    0.0                            NaN                  NaN
#
#    doc_neutrality_value  doc_neutrality_justification  doc_neutrality_url  \
# 0                   1.0                           NaN                 NaN
# 1                  -1.0                           NaN                 NaN
# 2                  -1.0                           NaN                 NaN
# 3                   2.0                           NaN                 NaN
# 4                   2.0                           NaN                 NaN
#
#    doc_comprehensibility_value  doc_comprehensibility_justification  \
# 0                          1.0                                  NaN
# 1                          2.0                                  NaN
# 2                          2.0                                  NaN
# 3                          2.0                                  NaN
# 4                          2.0                                  NaN
#
#    doc_comprehensibility_url  doc_precision_value  \
# 0                        NaN                  1.0
# 1                        NaN                  2.0
# 2                        NaN                  2.0
# 3                        NaN                  2.0
# 4                        NaN                  2.0
#
#    doc_precision_justification  doc_precision_url  doc_completeness_value  \
# 0                          NaN                NaN                    -1.0
# 1                          NaN                NaN                     2.0
# 2                          NaN                NaN                    -1.0
# 3                          NaN                NaN                     2.0
# 4                          NaN                NaN                     2.0
#
#    doc_completeness_justification  doc_completeness_url  \
# 0                             NaN                   NaN
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
#
#    doc_speaker's-trustworthiness_value  \
# 0                                  0.0
# 1                                  2.0
# 2                                  0.0
# 3                                  2.0
# 4                                  0.0
#
#    doc_speaker's-trustworthiness_justification  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    doc_speaker's-trustworthiness_url  doc_informativeness_value  \
# 0                                NaN                        1.0
# 1                                NaN                        2.0
# 2                                NaN                        1.0
# 3                                NaN                        0.0
# 4                                NaN                        2.0
#
#    doc_informativeness_justification  doc_informativeness_url  doc_accesses  \
# 0                                NaN                      NaN           1.0
# 1                                NaN                      NaN           1.0
# 2                                NaN                      NaN           1.0
# 3                                NaN                      NaN           1.0
# 4                                NaN                      NaN           1.0
#
#    doc_time_elapsed
# 0            175.61
# 1             88.39
# 2             84.60
# 3             53.41
# 4            361.84

# %%
numeric_features.tail()
# Out:
#       tries_amount  questionnaire_amount  dimensions_amount  document_amount  \
# 2195            10                     4                  9               11
# 2196            10                     4                  9               11
# 2197            10                     4                  9               11
# 2198            10                     4                  9               11
# 2199            10                     4                  9               11
#
#       current_try  q_0_age_value  q_0_school_value  q_0_taxes_value  \
# 2195            1            3.0               3.0              6.0
# 2196            1            3.0               3.0              6.0
# 2197            1            3.0               3.0              6.0
# 2198            1            3.0               3.0              6.0
# 2199            1            3.0               3.0              6.0
#
#       q_0_political_views_value  q_0_consideration_value  \
# 2195                        2.0                      1.0
# 2196                        2.0                      1.0
# 2197                        2.0                      1.0
# 2198                        2.0                      1.0
# 2199                        2.0                      1.0
#
#       q_0_southern_border_value  q_0_environment_value  q_0_time_elapsed  \
# 2195                        2.0                    0.0            371.26
# 2196                        2.0                    0.0            371.26
# 2197                        2.0                    0.0            371.26
# 2198                        2.0                    0.0            371.26
# 2199                        2.0                    0.0            371.26
#
#       q_0_accesses  q_1_farmers_answer  q_1_farmers_value  q_1_time_elapsed  \
# 2195             1                 NaN                9.0            607.14
# 2196             1                 NaN                9.0            607.14
# 2197             1                 NaN                9.0            607.14
# 2198             1                 NaN                9.0            607.14
# 2199             1                 NaN                9.0            607.14
#
#       q_1_accesses  q_2_marks_answer  q_2_marks_value  q_2_time_elapsed  \
# 2195             1               NaN              5.0             13.72
# 2196             1               NaN              5.0             13.72
# 2197             1               NaN              5.0             13.72
# 2198             1               NaN              5.0             13.72
# 2199             1               NaN              5.0             13.72
#
#       q_2_accesses  q_3_athletics_answer  q_3_athletics_value  \
# 2195             1                   NaN                 16.0
# 2196             1                   NaN                 16.0
# 2197             1                   NaN                 16.0
# 2198             1                   NaN                 16.0
# 2199             1                   NaN                 16.0
#
#       q_3_time_elapsed  q_3_accesses  doc_index  doc_date  \
# 2195            161.39             1        6.0    2006.0
# 2196            161.39             1        7.0    2012.0
# 2197            161.39             1        8.0    2013.0
# 2198            161.39             1        9.0    2013.0
# 2199            161.39             1       10.0    2013.0
#
#       doc_ground_truth_value  doc_overall-truthfulness_value  \
# 2195                     2.0                             0.0
# 2196                     2.0                             0.0
# 2197                     3.0                             0.0
# 2198                     3.0                             0.0
# 2199                     2.0                             0.0
#
#       doc_overall-truthfulness_justification  doc_confidence_value  \
# 2195                                     NaN                   1.0
# 2196                                     NaN                   1.0
# 2197                                     NaN                   1.0
# 2198                                     NaN                   1.0
# 2199                                     NaN                   1.0
#
#       doc_confidence_justification  doc_confidence_url  doc_correctness_value  \
# 2195                           NaN                 NaN                    0.0
# 2196                           NaN                 NaN                    0.0
# 2197                           NaN                 NaN                    0.0
# 2198                           NaN                 NaN                    0.0
# 2199                           NaN                 NaN                    0.0
#
#       doc_correctness_justification  doc_correctness_url  \
# 2195                            NaN                  NaN
# 2196                            NaN                  NaN
# 2197                            NaN                  NaN
# 2198                            NaN                  NaN
# 2199                            NaN                  NaN
#
#       doc_neutrality_value  doc_neutrality_justification  doc_neutrality_url  \
# 2195                   1.0                           NaN                 NaN
# 2196                   1.0                           NaN                 NaN
# 2197                   1.0                           NaN                 NaN
# 2198                   1.0                           NaN                 NaN
# 2199                   1.0                           NaN                 NaN
#
#       doc_comprehensibility_value  doc_comprehensibility_justification  \
# 2195                          1.0                                  NaN
# 2196                          0.0                                  NaN
# 2197                          1.0                                  NaN
# 2198                          1.0                                  NaN
# 2199                          0.0                                  NaN
#
#       doc_comprehensibility_url  doc_precision_value  \
# 2195                        NaN                  0.0
# 2196                        NaN                  1.0
# 2197                        NaN                  0.0
# 2198                        NaN                  0.0
# 2199                        NaN                  1.0
#
#       doc_precision_justification  doc_precision_url  doc_completeness_value  \
# 2195                          NaN                NaN                     1.0
# 2196                          NaN                NaN                     0.0
# 2197                          NaN                NaN                     1.0
# 2198                          NaN                NaN                     1.0
# 2199                          NaN                NaN                     0.0
#
#       doc_completeness_justification  doc_completeness_url  \
# 2195                             NaN                   NaN
# 2196                             NaN                   NaN
# 2197                             NaN                   NaN
# 2198                             NaN                   NaN
# 2199                             NaN                   NaN
#
#       doc_speaker's-trustworthiness_value  \
# 2195                                  0.0
# 2196                                  1.0
# 2197                                  0.0
# 2198                                  0.0
# 2199                                  1.0
#
#       doc_speaker's-trustworthiness_justification  \
# 2195                                          NaN
# 2196                                          NaN
# 2197                                          NaN
# 2198                                          NaN
# 2199                                          NaN
#
#       doc_speaker's-trustworthiness_url  doc_informativeness_value  \
# 2195                                NaN                        0.0
# 2196                                NaN                        0.0
# 2197                                NaN                        1.0
# 2198                                NaN                        1.0
# 2199                                NaN                        0.0
#
#       doc_informativeness_justification  doc_informativeness_url  \
# 2195                                NaN                      NaN
# 2196                                NaN                      NaN
# 2197                                NaN                      NaN
# 2198                                NaN                      NaN
# 2199                                NaN                      NaN
#
#       doc_accesses  doc_time_elapsed
# 2195           1.0             74.91
# 2196           1.0             53.62
# 2197           1.0            115.88
# 2198           1.0             72.78
# 2199           1.0            113.93

# %%
categorical_features.describe()
# Out:
#        unit_id         q_0_age_question q_0_age_answer  \
# count     2200                     2200           2200
# unique     200                        1              4
# top     unit_1  What is your age range?          26-35
# freq        11                     2200           1045
#
#                                                                                     q_0_school_question  \
# count                                                                                              2200
# unique                                                                                                1
# top     What is the highest level of school you have completed or the highest degree you have received?
# freq                                                                                               2200
#
#                                  q_0_school_answer  \
# count                                         2200
# unique                                           5
# top     Four year college degree/bachelor’s degree
# freq                                          1144
#
#                                                                  q_0_taxes_question  \
# count                                                                          2200
# unique                                                                            1
# top     Last year what was your total family income from all sources, before taxes?
# freq                                                                           2200
#
#                   q_0_taxes_answer  \
# count                         2200
# unique                           9
# top     50,000 to less than 75,000
# freq                           473
#
#                                   q_0_political_views_question  \
# count                                                     2200
# unique                                                       1
# top     In general, would you describe your political views as
# freq                                                      2200
#
#        q_0_political_views_answer  \
# count                        2200
# unique                          5
# top                       Liberal
# freq                          726
#
#                            q_0_consideration_question  \
# count                                            2200
# unique                                              1
# top     In politics today, do you consider yourself a
# freq                                             2200
#
#        q_0_consideration_answer  \
# count                      2200
# unique                        4
# top                    Democrat
# freq                       1012
#
#                                    q_0_southern_border_question  \
# count                                                      2200
# unique                                                        1
# top     Should the U.S. build a wall along the southern border?
# freq                                                       2200
#
#        q_0_southern_border_answer  \
# count                        2200
# unique                          3
# top                      Disagree
# freq                         1177
#
#                                                                    q_0_environment_question  \
# count                                                                                  2200
# unique                                                                                    1
# top     Should the government increase environmental regulations to prevent climate change?
# freq                                                                                   2200
#
#        q_0_environment_answer  \
# count                    2200
# unique                      3
# top                     Agree
# freq                     1870
#
#                                                                                                                           q_1_farmers_question  \
# count                                                                                                                                     2200
# unique                                                                                                                                       1
# top     If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# freq                                                                                                                                      2200
#
#                                                                                                         q_2_marks_question  \
# count                                                                                                                 2200
# unique                                                                                                                   1
# top     Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# freq                                                                                                                  2200
#
#                                                                                                                                                             q_3_athletics_question  \
# count                                                                                                                                                                         2200
# unique                                                                                                                                                                           1
# top     In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# freq                                                                                                                                                                          2200
#
#        doc_name  \
# count      2200
# unique      182
# top        HIGH
# freq        200
#
#                                                            doc_statement  \
# count                                                               2200
# unique                                                               181
# top     If I were not a Formula One pilot, I would be a football player.
# freq                                                                 201
#
#         doc_claimant doc_originatedFrom doc_ground_truth_abc_label  \
# count           2200               1600                        600
# unique           112                  6                          3
# top     Barack Obama  Public appearance                 in-between
# freq             330                400                        200
#
#        doc_ground_truth_abc_verdict doc_ground_truth_politifact_label  \
# count                           600                              1199
# unique                           30                                 6
# top                       incorrect                              true
# freq                             80                               203
#
#         doc_source doc_overall-truthfulness_label  \
# count         2200                           2200
# unique           3                              5
# top     politifact                          agree
# freq          1199                            698
#
#                                                                doc_overall-truthfulness_url  \
# count                                                                                  2200
# unique                                                                                 1498
# top     https://www.bartleby.com/essay/Barack-Obama-Yes-We-Can!-Famous-Speech-F3B9QC84C8BRA
# freq                                                                                     29
#
#        doc_confidence_label doc_correctness_label doc_neutrality_label  \
# count                  2200                  2200                 2200
# unique                    5                     5                    5
# top                   agree                 agree                agree
# freq                    638                   735                  623
#
#        doc_comprehensibility_label doc_precision_label doc_completeness_label  \
# count                         2200                2200                   2200
# unique                           5                   5                      5
# top                          agree               agree                  agree
# freq                           881                 817                    668
#
#        doc_speaker's-trustworthiness_label doc_informativeness_label
# count                                 2200                      2200
# unique                                   5                         5
# top                                  agree                     agree
# freq                                   682                       831

# %%
interest_features = [
    "q_0_age_answer", 
    "q_0_school_answer", 
    "q_0_taxes_answer", 
    "q_0_political_views_answer", 
    "q_0_consideration_answer", 
    "q_0_southern_border_answer", 
    "q_0_environment_answer", 
    "doc_ground_truth_abc_label", 
    "doc_ground_truth_politifact_label", 
    "doc_overall-truthfulness_label"
]

for i in interest_features:
    print(i, categorical_features[i].unique(), "\n")
# Out:
# q_0_age_answer ['26-35' '50-80' '19-25' '36-50']
#
# q_0_school_answer ['Some college (some community college, associate’s degree)'
#  'Postgraduate or professional degree, including master’s, doctorate, medical or law degree'
#  'Four year college degree/bachelor’s degree'
#  'High school graduate or GED (includes technical/vocational training that doesn’t towards college credit)'
#  'Some postgraduate or professional schooling, no postgraduate degree']
#
# q_0_taxes_answer ['30,000 to less than 40,000' '50,000 to less than 75,000'
#  '100,000 to less than 150,000' '75,000 to less than 100,000'
#  '10,000 to less than 20,000' '40,000 to less than 50,000'
#  'Less than 10,000' '20,000 to less than 30,000' '150,000 or more']
#
# q_0_political_views_answer ['Very liberal' 'Liberal' 'Moderate' 'Conservative' 'Very conservative']
#
# q_0_consideration_answer ['Independent' 'Republican' 'Democrat' 'Something else']
#
# q_0_southern_border_answer ['Disagree' 'No opinion either way' 'Agree']
#
# q_0_environment_answer ['Agree' 'Disagree' 'No opinion either way']
#
# doc_ground_truth_abc_label ['in-between' 'negative' 'positive' nan]
#
# doc_ground_truth_politifact_label [nan 'half-true' 'false' 'pants-on-fire' 'mostly-true' 'true'
#  'barely-true']
#
# doc_overall-truthfulness_label ['agree' 'completely-agree' 'neither-agree-nor-disagree' 'disagree'
#  'completely-disagree']

# %%
categorical_features.head()
# Out:
#   unit_id         q_0_age_question q_0_age_answer  \
# 0  unit_1  What is your age range?          26-35
# 1  unit_1  What is your age range?          26-35
# 2  unit_1  What is your age range?          26-35
# 3  unit_1  What is your age range?          26-35
# 4  unit_1  What is your age range?          26-35
#
#                                                                                q_0_school_question  \
# 0  What is the highest level of school you have completed or the highest degree you have received?
# 1  What is the highest level of school you have completed or the highest degree you have received?
# 2  What is the highest level of school you have completed or the highest degree you have received?
# 3  What is the highest level of school you have completed or the highest degree you have received?
# 4  What is the highest level of school you have completed or the highest degree you have received?
#
#                                            q_0_school_answer  \
# 0  Some college (some community college, associate’s degree)
# 1  Some college (some community college, associate’s degree)
# 2  Some college (some community college, associate’s degree)
# 3  Some college (some community college, associate’s degree)
# 4  Some college (some community college, associate’s degree)
#
#                                                             q_0_taxes_question  \
# 0  Last year what was your total family income from all sources, before taxes?
# 1  Last year what was your total family income from all sources, before taxes?
# 2  Last year what was your total family income from all sources, before taxes?
# 3  Last year what was your total family income from all sources, before taxes?
# 4  Last year what was your total family income from all sources, before taxes?
#
#              q_0_taxes_answer  \
# 0  30,000 to less than 40,000
# 1  30,000 to less than 40,000
# 2  30,000 to less than 40,000
# 3  30,000 to less than 40,000
# 4  30,000 to less than 40,000
#
#                              q_0_political_views_question  \
# 0  In general, would you describe your political views as
# 1  In general, would you describe your political views as
# 2  In general, would you describe your political views as
# 3  In general, would you describe your political views as
# 4  In general, would you describe your political views as
#
#   q_0_political_views_answer                     q_0_consideration_question  \
# 0               Very liberal  In politics today, do you consider yourself a
# 1               Very liberal  In politics today, do you consider yourself a
# 2               Very liberal  In politics today, do you consider yourself a
# 3               Very liberal  In politics today, do you consider yourself a
# 4               Very liberal  In politics today, do you consider yourself a
#
#   q_0_consideration_answer  \
# 0              Independent
# 1              Independent
# 2              Independent
# 3              Independent
# 4              Independent
#
#                               q_0_southern_border_question  \
# 0  Should the U.S. build a wall along the southern border?
# 1  Should the U.S. build a wall along the southern border?
# 2  Should the U.S. build a wall along the southern border?
# 3  Should the U.S. build a wall along the southern border?
# 4  Should the U.S. build a wall along the southern border?
#
#   q_0_southern_border_answer  \
# 0                   Disagree
# 1                   Disagree
# 2                   Disagree
# 3                   Disagree
# 4                   Disagree
#
#                                                               q_0_environment_question  \
# 0  Should the government increase environmental regulations to prevent climate change?
# 1  Should the government increase environmental regulations to prevent climate change?
# 2  Should the government increase environmental regulations to prevent climate change?
# 3  Should the government increase environmental regulations to prevent climate change?
# 4  Should the government increase environmental regulations to prevent climate change?
#
#   q_0_environment_answer  \
# 0                  Agree
# 1                  Agree
# 2                  Agree
# 3                  Agree
# 4                  Agree
#
#                                                                                                                      q_1_farmers_question  \
# 0  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 1  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 2  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 3  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 4  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
#
#                                                                                                    q_2_marks_question  \
# 0  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 1  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 2  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 3  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 4  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
#
#                                                                                                                                                        q_3_athletics_question  \
# 0  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 1  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 2  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 3  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 4  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
#
#                   doc_name  \
# 0  Liberal_In_Between_doc1
# 1      Labor_Negative_doc3
# 2      Labor_Positive_doc1
# 3                     HIGH
# 4       REP_HALFTRUE_doc10
#
#                                                                                                                                                                                                                                                                                          doc_statement  \
# 0  What the states do is a matter for the states The constitution provides that marriage is a responsibility of the Commonwealth parliament And as you know the Commonwealth parliament recently voted on this subject and by a fairly decisive margin decided to stick with the existing Marriage Act
# 1                                                                                                                             Mr Abbott seems to be suffering from just a little bit of amnesia Mr Rudd saidWhen he was health minister he cut 1 billion from the public hospitals budget of Australia
# 2                                                                                         Australia is one of only eight countries given a rating of AAA with a stable outlook from all three credit rating agenciesThese are the real facts and no amount of negative political spin will change that
# 3                                                                                                                                                                                                                                                                                         Yes, We can!
# 4                                                                                                                                                                                          In the fall of 2009 only 21 percent of Texas high school graduates enrolled in a fouryear public university
#
#    doc_claimant doc_originatedFrom doc_ground_truth_abc_label  \
# 0   Tony Abbott                NaN                 in-between
# 1    Kevin Rudd                NaN                   negative
# 2    Kevin Rudd                NaN                   positive
# 3  Barack Obama  Public appearance                        NaN
# 4  Todd Staples       social media                        NaN
#
#   doc_ground_truth_abc_verdict doc_ground_truth_politifact_label  \
# 0              lawyer's picnic                               NaN
# 1                        wrong                               NaN
# 2                     accurate                               NaN
# 3                          NaN                               NaN
# 4                          NaN                         half-true
#
#       doc_source doc_overall-truthfulness_label  \
# 0            abc                          agree
# 1            abc               completely-agree
# 2            abc               completely-agree
# 3  gold_question               completely-agree
# 4     politifact     neither-agree-nor-disagree
#
#                                                                                                                doc_overall-truthfulness_url  \
# 0                                  https://www.thenewamerican.com/usnews/constitution/item/15954-may-the-federal-government-define-marriage
# 1                                                 https://www.theguardian.com/world/2014/may/19/hospital-cuts-begin-july-tony-abbott-admits
# 2                                                      https://www.reuters.com/article/us-health-coronavirus-australia-rating-idUSKBN21I0DS
# 3                                                       https://www.bartleby.com/essay/Barack-Obama-Yes-We-Can!-Famous-Speech-F3B9QC84C8BRA
# 4  https://www.dallasnews.com/news/education/2011/08/27/students-in-wealthier-texas-districts-much-likelier-to-go-to-out-of-state-colleges/
#
#          doc_confidence_label       doc_correctness_label  \
# 0                    disagree                       agree
# 1  neither-agree-nor-disagree            completely-agree
# 2  neither-agree-nor-disagree  neither-agree-nor-disagree
# 3            completely-agree            completely-agree
# 4                    disagree  neither-agree-nor-disagree
#
#   doc_neutrality_label doc_comprehensibility_label doc_precision_label  \
# 0                agree                       agree               agree
# 1             disagree            completely-agree    completely-agree
# 2             disagree            completely-agree    completely-agree
# 3     completely-agree            completely-agree    completely-agree
# 4     completely-agree            completely-agree    completely-agree
#
#   doc_completeness_label doc_speaker's-trustworthiness_label  \
# 0               disagree          neither-agree-nor-disagree
# 1       completely-agree                    completely-agree
# 2               disagree          neither-agree-nor-disagree
# 3       completely-agree                    completely-agree
# 4       completely-agree          neither-agree-nor-disagree
#
#     doc_informativeness_label
# 0                       agree
# 1            completely-agree
# 2                       agree
# 3  neither-agree-nor-disagree
# 4            completely-agree

# %%
categorical_features.tail()
# Out:
#        unit_id         q_0_age_question q_0_age_answer  \
# 2195  unit_156  What is your age range?          36-50
# 2196  unit_156  What is your age range?          36-50
# 2197  unit_156  What is your age range?          36-50
# 2198  unit_156  What is your age range?          36-50
# 2199  unit_156  What is your age range?          36-50
#
#                                                                                   q_0_school_question  \
# 2195  What is the highest level of school you have completed or the highest degree you have received?
# 2196  What is the highest level of school you have completed or the highest degree you have received?
# 2197  What is the highest level of school you have completed or the highest degree you have received?
# 2198  What is the highest level of school you have completed or the highest degree you have received?
# 2199  What is the highest level of school you have completed or the highest degree you have received?
#
#                                q_0_school_answer  \
# 2195  Four year college degree/bachelor’s degree
# 2196  Four year college degree/bachelor’s degree
# 2197  Four year college degree/bachelor’s degree
# 2198  Four year college degree/bachelor’s degree
# 2199  Four year college degree/bachelor’s degree
#
#                                                                q_0_taxes_question  \
# 2195  Last year what was your total family income from all sources, before taxes?
# 2196  Last year what was your total family income from all sources, before taxes?
# 2197  Last year what was your total family income from all sources, before taxes?
# 2198  Last year what was your total family income from all sources, before taxes?
# 2199  Last year what was your total family income from all sources, before taxes?
#
#                  q_0_taxes_answer  \
# 2195  75,000 to less than 100,000
# 2196  75,000 to less than 100,000
# 2197  75,000 to less than 100,000
# 2198  75,000 to less than 100,000
# 2199  75,000 to less than 100,000
#
#                                 q_0_political_views_question  \
# 2195  In general, would you describe your political views as
# 2196  In general, would you describe your political views as
# 2197  In general, would you describe your political views as
# 2198  In general, would you describe your political views as
# 2199  In general, would you describe your political views as
#
#      q_0_political_views_answer  \
# 2195                   Moderate
# 2196                   Moderate
# 2197                   Moderate
# 2198                   Moderate
# 2199                   Moderate
#
#                          q_0_consideration_question q_0_consideration_answer  \
# 2195  In politics today, do you consider yourself a                 Democrat
# 2196  In politics today, do you consider yourself a                 Democrat
# 2197  In politics today, do you consider yourself a                 Democrat
# 2198  In politics today, do you consider yourself a                 Democrat
# 2199  In politics today, do you consider yourself a                 Democrat
#
#                                  q_0_southern_border_question  \
# 2195  Should the U.S. build a wall along the southern border?
# 2196  Should the U.S. build a wall along the southern border?
# 2197  Should the U.S. build a wall along the southern border?
# 2198  Should the U.S. build a wall along the southern border?
# 2199  Should the U.S. build a wall along the southern border?
#
#      q_0_southern_border_answer  \
# 2195      No opinion either way
# 2196      No opinion either way
# 2197      No opinion either way
# 2198      No opinion either way
# 2199      No opinion either way
#
#                                                                  q_0_environment_question  \
# 2195  Should the government increase environmental regulations to prevent climate change?
# 2196  Should the government increase environmental regulations to prevent climate change?
# 2197  Should the government increase environmental regulations to prevent climate change?
# 2198  Should the government increase environmental regulations to prevent climate change?
# 2199  Should the government increase environmental regulations to prevent climate change?
#
#      q_0_environment_answer  \
# 2195                  Agree
# 2196                  Agree
# 2197                  Agree
# 2198                  Agree
# 2199                  Agree
#
#                                                                                                                         q_1_farmers_question  \
# 2195  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 2196  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 2197  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 2198  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
# 2199  If three farmers can plant three trees in three hours, how long (i.e., how many hours) would it take nine farmers to plant nine trees?
#
#                                                                                                       q_2_marks_question  \
# 2195  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 2196  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 2197  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 2198  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
# 2199  Sean received both the 5th highest and the 5th lowest mark in the class. How many students are there in the class?
#
#                                                                                                                                                           q_3_athletics_question  \
# 2195  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 2196  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 2197  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 2198  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
# 2199  In an athletics team, females are four times more likely to win a medal than males. This year the team has won 20 medals so far. How many of these have been won by males?
#
#                    doc_name  \
# 2195                    LOW
# 2196           REP_LIE_doc8
# 2197  Labor_In_Between_doc1
# 2198    Labor_Positive_doc3
# 2199  Liberal_Negative_doc1
#
#                                                                                                                                                                                    doc_statement  \
# 2195                                                                                                                            If I were not a Formula One pilot, I would be a football player.
# 2196                                                                                                                             Says I was the first governor in America to endorse Mitt Romney
# 2197  If you take the unaccompanied children I am their legal guardian I am in a situation where I have to substitute the level of responsibility by law that would otherwise equate to a parent
# 2198                                                                            Under this government the tax to GDP ratio has in the period weve been in office been an average of 227 per cent
# 2199                                                      We left the country with net assets of 70 billion where if we are elected on the 7th of September we inherit debt going to 400 billion
#
#          doc_claimant doc_originatedFrom doc_ground_truth_abc_label  \
# 2195  Abraham Lincoln  Public appearance                        NaN
# 2196   Chris Christie     a news release                        NaN
# 2197       Tony Burke                NaN                 in-between
# 2198       Kevin Rudd                NaN                   positive
# 2199       Joe Hockey                NaN                   negative
#
#      doc_ground_truth_abc_verdict doc_ground_truth_politifact_label  \
# 2195                          NaN                               NaN
# 2196                          NaN                     pants-on-fire
# 2197                   incomplete                               NaN
# 2198                   checks out                               NaN
# 2199                 exaggeration                               NaN
#
#          doc_source doc_overall-truthfulness_label  \
# 2195  gold_question     neither-agree-nor-disagree
# 2196     politifact     neither-agree-nor-disagree
# 2197            abc     neither-agree-nor-disagree
# 2198            abc     neither-agree-nor-disagree
# 2199            abc     neither-agree-nor-disagree
#
#                                                                            doc_overall-truthfulness_url  \
# 2195  https://www.quora.com/How-old-is-too-late-to-try-and-become-a-professional-football-soccer-player
# 2196                                            https://en.wikipedia.org/wiki/Governor-General_of_India
# 2197                                                    https://en.wikipedia.org/wiki/Tom_Burke_(actor)
# 2198                                            https://commonenglisherrors.com/past-year-vs-last-year/
# 2199                                                           https://en.wikipedia.org/wiki/Joe_Hockey
#
#      doc_confidence_label       doc_correctness_label doc_neutrality_label  \
# 2195                agree  neither-agree-nor-disagree                agree
# 2196                agree  neither-agree-nor-disagree                agree
# 2197                agree  neither-agree-nor-disagree                agree
# 2198                agree  neither-agree-nor-disagree                agree
# 2199                agree  neither-agree-nor-disagree                agree
#
#      doc_comprehensibility_label         doc_precision_label  \
# 2195                       agree  neither-agree-nor-disagree
# 2196  neither-agree-nor-disagree                       agree
# 2197                       agree  neither-agree-nor-disagree
# 2198                       agree  neither-agree-nor-disagree
# 2199  neither-agree-nor-disagree                       agree
#
#           doc_completeness_label doc_speaker's-trustworthiness_label  \
# 2195                       agree          neither-agree-nor-disagree
# 2196  neither-agree-nor-disagree                               agree
# 2197                       agree          neither-agree-nor-disagree
# 2198                       agree          neither-agree-nor-disagree
# 2199  neither-agree-nor-disagree                               agree
#
#        doc_informativeness_label
# 2195  neither-agree-nor-disagree
# 2196  neither-agree-nor-disagree
# 2197                       agree
# 2198                       agree
# 2199  neither-agree-nor-disagree

# %%
# add columns of CRT scores
q1_value = df["q_1_farmers_value"]
q1_score = (q1_value == 3.0).astype("int")
df["q_1_farmers_score"] = q1_score

q2_value = df["q_2_marks_value"]
q2_score = (q2_value == 9.0).astype("int")
df["q_2_marks_score"] = q2_score

q3_value = df["q_3_athletics_value"]
q3_score = (q3_value == 16.0).astype("int")
df["q_3_athletics_score"] = q3_score

df["overall_crt_score"] = df["q_1_farmers_score"] + df["q_2_marks_score"] + df["q_3_athletics_score"]

df[["q_1_farmers_score", "q_2_marks_score", "q_3_athletics_score", "overall_crt_score"]].describe()
# Out:
#        q_1_farmers_score  q_2_marks_score  q_3_athletics_score  \
# count        2200.000000      2200.000000          2200.000000
# mean            0.500000         0.295000             0.075000
# std             0.500114         0.456146             0.263451
# min             0.000000         0.000000             0.000000
# 25%             0.000000         0.000000             0.000000
# 50%             0.500000         0.000000             0.000000
# 75%             1.000000         1.000000             0.000000
# max             1.000000         1.000000             1.000000
#
#        overall_crt_score
# count        2200.000000
# mean            0.870000
# std             0.826687
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             1.000000
# max             3.000000

# %%
# assessment result comparing to the ground truth
df["doc_assessment_quality"] = 0
df["doc_ground_truth_value"] = df["doc_ground_truth_value"] - 2
for index, row in df.iterrows():
    if row["doc_ground_truth_value"] == row["doc_overall-truthfulness_value"]:
        df.at[index, "doc_assessment_quality"] = 2
    elif row["doc_ground_truth_value"] * row["doc_overall-truthfulness_value"] > 0:
        df.at[index, "doc_assessment_quality"] = 1

# %%
# save a subset of relevant features
df_user_profile = df[[
    "unit_id", 
    "q_0_age_answer", 
    "q_0_school_answer", 
    "q_0_taxes_answer", 
    "q_0_political_views_answer", 
    "q_0_consideration_answer", 
    "q_0_southern_border_answer", 
    "q_0_environment_answer", 
    "q_0_age_value",
    "q_0_school_value",
    "q_0_taxes_value",
    "q_0_political_views_value",
    "q_0_consideration_value",
    "q_0_southern_border_value",
    "q_0_environment_value",
    "q_1_farmers_score", 
    "q_2_marks_score", 
    "q_3_athletics_score", 
    "overall_crt_score", 
    "q_0_time_elapsed", 
    "q_1_time_elapsed", 
    "q_2_time_elapsed", 
    "q_3_time_elapsed", 
    "q_0_accesses", 
    "q_1_accesses", 
    "q_2_accesses", 
    "q_3_accesses"
]]
df_user_profile = df_user_profile.drop_duplicates()

df_assessment = df[[
    "unit_id", 
    "doc_ground_truth_value", 
    "doc_overall-truthfulness_value", 
    "doc_confidence_value", 
    "doc_correctness_value", 
    "doc_neutrality_value", 
    "doc_comprehensibility_value", 
    "doc_precision_value", 
    "doc_completeness_value", 
    "doc_speaker's-trustworthiness_value", 
    "doc_informativeness_value",  
    "doc_time_elapsed", 
    "doc_accesses", 
    "doc_assessment_quality"
]]

df_user_profile.to_csv("../data/IPM_worker_profile.csv", index=False)
df_assessment.to_csv("../data/IPM_assessment.csv", index=False)
